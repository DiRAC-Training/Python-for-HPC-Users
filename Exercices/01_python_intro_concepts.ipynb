# %% [markdown]
# # Introduction to Python for Research Computing and HPC
# ### Part 1: Concepts and worked examples
#
# This notebook introduces Python as a programming language for research computing and HPC.
#
# You will learn how to run Python interactively, create and execute simple Python programs (in this notebook, "cells" take the place of scripts), and use the `print()` function to display information.
#
# ## Learning Objectives
#
# - Explain why Python is commonly used in research computing and HPC.
# - Describe the difference between interactive Python sessions and Python scripts.
# - Run simple Python commands using the Python interpreter.
# - Create, save and execute a basic Python program.
# - Use the `print()` function to display text and numerical values.
# - Add comments to Python programs to improve readability and maintainability.
#
# > **Note for students:** run each code cell with **Shift+Enter**. This notebook is for reading and running the examples. When you're ready to practise on your own, move on to the companion notebook: **Part 2: Exercises**.

# %% [markdown]
# ## Introduction
#
# Python is one of the most widely used programming languages in research computing. It is popular because it is relatively easy to read, has a large scientific community, and provides access to many powerful libraries for data analysis, automation, visualisation and scientific computing.
#
# In HPC, Python is often used to support research workflows. Researchers may use Python to prepare input files, process simulation outputs, analyse datasets, create plots, or automate repetitive tasks. Python is not always used to replace highly optimised code written in languages such as C, C++ or Fortran. Instead, it often acts as a flexible tool that helps researchers connect different parts of their workflow together.
#
# | Research task | How Python can help |
# |---|---|
# | Preparing a simulation | Create or modify input files automatically. |
# | Running repeated tasks | Automate commands that would otherwise be typed by hand. |
# | Analysing output | Read data files and calculate useful results. |
# | Sharing methods | Create scripts that can be saved, reused and shared. |
#
# By completing this lesson, you will develop the confidence to write, save, and run your first Python programs and establish the foundations needed for the rest of the course.

# %% [markdown]
# ## What is Python?
#
# Python is a high-level programming language. A high-level language is designed to be read and written by people more easily than lower-level machine instructions. This makes Python a good language for beginners, but it is also powerful enough to be used in professional research and software development.
#
# Python code often looks close to plain English. This is one of the reasons it is widely used in education and research. A readable language makes it easier to understand what a program is doing, return to old code, and share scripts with colleagues.
#
# For example, the following line tells Python to display a message. Run the cell below:

# %%
print("Hello, world!")

# %% [markdown]
# Even if you have never programmed before, you can probably make a reasonable guess about what this line does. It prints, or displays, the message `Hello, world!`.
#
# ## Why researchers use Python
#
# Researchers often need to solve problems quickly and accurately. They may need to analyse data, automate calculations, generate plots, or process many files. Python is useful because it allows researchers to write programs quickly while still providing access to powerful scientific tools.
#
# Python can help researchers to:
#
# - Automate repetitive tasks.
# - Analyse experimental or simulation data.
# - Create figures and visualisations.
# - Develop reproducible computational workflows.
# - Connect different tools and stages of a research process.
#
# ## Python in research computing
#
# Python is often used alongside specialist scientific libraries. These libraries provide tested, efficient tools for common research tasks. For example, researchers may use libraries for numerical calculations, data analysis, plotting or machine learning.
#
# You do not need to know these libraries yet. In this lesson, the important point is that Python provides a foundation on which more advanced research computing skills can be built.
#
# | Python role | Example use |
# |---|---|
# | Automation | Rename files, generate job scripts, or repeat calculations. |
# | Data processing | Read output files and calculate summaries. |
# | Visualisation | Create plots and figures from results. |
# | Workflow control | Connect simulation, analysis, and reporting steps. |
#
# ### A simple view of a research workflow
#
# ```
# Research question
#        |
#        v
# Write or run code
#        |
#        v
# Generate data
#        |
#        v
# Analyse results with Python
#        |
#        v
# Create figures or reports
# ```
#
# This diagram shows one common pattern. Python may not be responsible for every step, but it is often used to prepare, organise, analyse, or present the results of computational research.

# %% [markdown]
# ## Running Python
#
# There are several ways to use Python. In this lesson, we will focus on two common approaches:
#
# 1. Using Python interactively.
# 2. Writing and running Python scripts.
#
# Both approaches are useful. The best choice depends on what you are trying to do.
#
# ### Which Python to use
#
# On most HPC systems there will be a default Python on your system. This is fine for now, but as you get more acquainted with Python, you may want to load a specific version that has all the required libraries you need. It is also good practice when submitting a job to a compute node to specify the Python version as well as any other required software. This is done with the standard `module load` command.
#
# ### Interactive Python
#
# Interactive Python allows you to type one command at a time and immediately see the result. This is useful when you are learning, testing a small idea, or checking a quick calculation.
#
# An interactive Python session on a terminal usually shows a prompt that looks like this:
#
# ```
# >>>
# ```
#
# You type your command after the prompt, e.g. `>>> print("Hello, world!")`.
#
# **In this notebook, each code cell behaves like a single interactive command** — you run it and immediately see the result underneath, just like the `>>>` prompt on a terminal.
#
# ### When to use interactive Python
#
# Interactive Python is useful when you want to:
#
# - Try out a single command.
# - Test a small calculation.
# - Explore how a function works.
# - Learn a new Python idea without creating a file.
#
# However, interactive commands are not normally saved as a reusable program. For larger tasks or for work that needs to be repeated, it is better to write a script.
#
# ### Python scripts
#
# A Python script is a text file containing Python code. The file usually has a name ending in `.py`, e.g. `hello.py`.
#
# A script allows you to save your commands, edit them later, and run them again. This is very important in research computing because reproducibility matters. If you save your analysis as a script, you or another researcher can run the same steps again in the future.
#
# You would run a script from the command line using:
#
# ```
# python hello.py
# ```
#
# **A Jupyter notebook sits between these two approaches**: like an interactive session, you see results immediately after each cell; like a script, the whole notebook can be saved, re-run from top to bottom, and shared with others.
#
# | Approach | Best used for | Limitation |
# |---|---|---|
# | Interactive Python | Testing ideas and trying small commands. | Commands are not usually saved as a reusable program. |
# | Python script | Saving, sharing, and repeating a program. | You need to create and manage a file. |
# | Jupyter notebook | Testing ideas *and* keeping a saved, shareable record. | Cells can be run out of order, which can cause confusion if you're not careful (see note below). |
#
# > **A note on running order:** In a notebook, cells don't have to run top-to-bottom — you could run cell 5 before cell 2. This is powerful for experimenting, but it can also cause confusing bugs if a later cell depends on an earlier one that hasn't been run yet (or has changed since). A good habit: periodically use the menu option **"Restart Kernel and Run All"** to check your notebook works cleanly from top to bottom — this is the notebook equivalent of running a script and is important for reproducibility.

# %%
print("Hello, world!")

# %% [markdown]
# ## Your first Python program
#
# The traditional first program in many programming languages displays the message `Hello, world!`. This is a small but useful test because it confirms that Python is running and that you can display output.
#
# Let's look carefully at the line you just ran:
#
# | Part of the code | Meaning |
# |---|---|
# | `print` | The name of the function that displays information. |
# | `( )` | Brackets that contain the information we want to give to the function. |
# | `"Hello, world!"` | The text we want Python to display. |
#
# The quotation marks are important. They tell Python that `Hello, world!` is text. In programming, text is often called a **string**.
#
# ### Try changing the message
#
# Run the cell below, then edit the text and run it again:

# %%
print("Hello from Python!")
print("I am learning Python for HPC.")

# %% [markdown]
# Notice that each `print()` command displays its output on a new line.
#
# ## The print() function
#
# The `print()` function displays information on the screen. It is one of the first Python functions that most learners use because it provides immediate feedback.
#
# You can use `print()` to display text, numbers, and simple calculations.
#
# ### Printing text

# %%
print("Python is useful for research.")

# %% [markdown]
# ### Printing numbers

# %%
print(42)

# %% [markdown]
# Numbers do not need quotation marks. If you put a number in quotation marks, Python treats it as text rather than as a number. This distinction will become more important in later lessons.
#
# ### Printing more than one value
#
# You can give `print()` more than one item by separating the items with commas.

# %%
print("Temperature:", 25)

# %% [markdown]
# Python automatically adds a space between the items when it displays them.
#
# ### Printing calculations
#
# Python can also calculate a value before displaying it.

# %%
print(12 + 8)

# %% [markdown]
# In this example, Python evaluates `12 + 8` first, then prints the result.
#
# ### Common arithmetic operators
#
# | Operator | Meaning | Example | Result |
# |---|---|---|---|
# | `+` | Addition | `10 + 5` | 15 |
# | `-` | Subtraction | `10 - 5` | 5 |
# | `*` | Multiplication | `10 * 5` | 50 |
# | `/` | Division | `10 / 5` | 2.0 |
#
# > **A quick note:** division gives an answer with a decimal point, like `2.0`, even when the answer is a whole number. You don't need to know why yet — just expect to see `.0` appear after dividing, and don't worry about it for now. It will make sense once you learn about number types later in the course.

# %%
print(10 / 5)

# %% [markdown]
# ## Comments
#
# Comments are notes written inside code. Python ignores comments when the program runs, but comments are useful for humans reading the code.
#
# In Python, a comment begins with the `#` symbol.

# %%
# Calculate the number of hours
print(48 / 2)

# %% [markdown]
# Python ignores the first line because it is a comment. It runs the second line because it is Python code.
#
# ### Why comments are useful
#
# Comments help explain why a piece of code exists or what a section of code is intended to do. This is especially important in research computing because code may be reused, shared, reviewed, or returned to months later.
#
# Good comments can help:
#
# - You understand your own code when you return to it later.
# - Colleagues understand your method.
# - Future users reproduce your workflow.
# - Reviewers or collaborators check your assumptions.
#
# ### Good and poor comments
#
# A useful comment explains the purpose of the code:
#
# ```python
# # Convert the simulation runtime from hours to days
# print(72 / 24)
# ```
#
# A less useful comment simply repeats the code without adding meaning:
#
# ```python
# # Print 72 divided by 24
# print(72 / 24)
# ```
#
# As your programs become more complex, aim to write comments that explain *why* something is being done, not just *what* each line says.

# %% [markdown]
# ## Worked Examples
#
# The following examples show how the ideas in this lesson fit together. Read each example carefully, then run the cell to check your understanding.
#
# ### Example 1: Introducing yourself
#
# In this example, Python displays two lines of text. This is a useful first exercise because many programs begin by displaying status information or summaries.

# %%
print("Name: Alex Smith")
print("Department: Chemistry")

# %% [markdown]
# Each line uses the `print()` function. Because there are two `print()` statements, Python displays two lines of output.
#
# ### Example 2: Simple calculation
#
# Python can perform mathematical calculations directly. This example adds two numbers and displays the result.

# %%
print(12 + 8)

# %% [markdown]
# ### Example 3: Calculating simulation time
#
# Suppose a simulation runs for 72 hours. To convert hours into days, divide the number of hours by 24.

# %%
print(72 / 24)

# %% [markdown]
# The result is `3.0`, meaning the simulation ran for three days (remember the note above about the `.0`).
#
# ### Example 4: Adding comments
#
# This example uses a comment to explain the purpose of the calculation.

# %%
# Convert minutes to hours
print(180 / 60)

# %% [markdown]
# The comment does not change the result. Its purpose is to make the code easier to understand.
#
# ### Example 5: A simple HPC message
#
# Python scripts are often used to print progress messages. These messages can help you understand what your program is doing, especially when a task takes a long time.

# %%
print("Starting analysis")
print("Reading simulation output")
print("Analysis complete")

# %% [markdown]
# Progress messages are simple, but they can be very useful when running scripts on large datasets or remote systems.

# %% [markdown]
# ## Common beginner mistakes
#
# When learning Python, small typing mistakes are common. Do not be discouraged by error messages — they are part of programming and often tell you what needs to be fixed.
#
# Try running each of the broken examples below **on purpose**, read the error message Python gives you, then fix it in the cell underneath.
#
# ### Forgetting quotation marks
#
# This code is incorrect. Run it and read the error:

# %%
print(Hello)

# %% [markdown]
# Now fix it below (add quotation marks so `Hello` is treated as text):

# %%
# TODO: fix the line below
print(Hello)

# %% [markdown]
# ### Using the wrong capitalisation
#
# Python is case-sensitive. This means `print` and `Print` are not the same. Run the broken version below:

# %%
Print("Hello")

# %% [markdown]
# Now fix it below:

# %%
# TODO: fix the capitalisation
Print("Hello")

# %% [markdown]
# ### Forgetting brackets
#
# The `print()` function needs brackets. Run the broken version below (this is Python 2 style and will raise a `SyntaxError` in Python 3):

# %%
print "Hello"

# %% [markdown]
# Now fix it below:

# %%
# TODO: add brackets
print "Hello"

# %% [markdown]
# > **Filename note (scripts only):** this mistake doesn't apply inside a notebook, but it's worth knowing for later: Python scripts usually end in `.py`. Be careful not to accidentally save your file as `hello.py.txt` instead of `hello.py` — this is a common issue when using text editors that automatically add `.txt` to filenames.

# %% [markdown]
# ## A glimpse ahead
#
# Python's real power in research comes from its libraries. As a small preview, here's Python's built-in `random` library generating a random number — the sort of thing you might use to select a random sample, shuffle simulation seeds, or run a Monte Carlo test. You don't need to understand `import` yet; just notice how one extra line gives Python a whole new capability.

# %%
import random
print(random.randint(1, 100))

# %% [markdown]
# ## Summary
#
# In this lesson, you have been introduced to Python and written your first simple programs. You have learned that Python is widely used in research computing because it is readable, flexible, and supported by a large scientific ecosystem.
#
# You have also explored two ways of running Python. Interactive Python is useful for trying out individual commands and testing ideas, while Python scripts (and notebooks) are better for saved, repeatable, and shareable workflows.
#
# You have used the `print()` function to display text, numbers and calculations. You have also learned how comments can be used to explain code and improve readability.
#
# These are small but important first steps. Every larger Python program is built from simple statements like the ones you have used in this lesson.
#
# ### Key Points
#
# - **Python is widely used in research.** It is readable, flexible, and supported by many scientific tools.
# - **Interactive Python is useful for testing.** It allows you to run one command at a time and immediately see the result.
# - **Scripts are useful for reproducibility.** A saved script (or notebook) can be run again, shared, and stored with your research workflow.
# - **The `print()` function displays information.** It can display text, numbers, and calculated results.
# - **Comments help humans read code.** They explain the purpose of code and are ignored by Python.
#
# ### What's next
#
# Head to the companion notebook, **Part 2: Exercises**, to practise these ideas yourself. Each exercise there includes a self-check cell so you can confirm your answer is correct before moving on.
