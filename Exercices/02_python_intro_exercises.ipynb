# %% [markdown]
# # Introduction to Python for Research Computing and HPC
# ### Part 2: Exercises
#
# Complete the exercises below to practise the ideas from **Part 1: Concepts**. Try to type the code yourself rather than copying and pasting — this will help you become more familiar with Python syntax.
#
# **How the self-check cells work:** each exercise has a code cell for your solution, followed by a check cell. The first line of your solution cell, `%%capture my_output`, quietly saves whatever your cell prints so the check cell can look at it — you don't need to understand this line, just leave it at the top of the cell. Run your solution cell, then run the check cell underneath it. It will tell you if your answer is correct.

# %% [markdown]
# ## Exercise 1: Your first program
#
# Write Python code that displays the message:
#
# ```
# Hello from Python!
# ```
#
# *Hint: Use the `print()` function and place the message inside quotation marks.*

# %%
# %%capture my_output
# TODO: print "Hello from Python!"

# %%
assert my_output.stdout.strip() == "Hello from Python!", (
    f"Not quite yet — your output was: {my_output.stdout!r}"
)
print("Correct! Well done.")

# %% [markdown]
# ## Exercise 2: Personal information
#
# Write code that displays:
#
# - Your name.
# - Your institution.
# - Your research area.
#
# Your output might look like this:
#
# ```
# Name: Alex Smith
# Institution: Example University
# Research area: Computational chemistry
# ```
#
# **Extension:** Add one more line describing why you are learning Python.

# %%
# %%capture my_output
# TODO: print your name, institution, and research area
# Extension: add a line about why you are learning Python

# %%
lines = [l for l in my_output.stdout.splitlines() if l.strip()]
assert len(lines) >= 3, "Expected at least 3 lines of output (name, institution, research area)."
assert any(l.lower().startswith("name") for l in lines), "Expected a line starting with 'Name:'"
assert any(l.lower().startswith("institution") for l in lines), "Expected a line starting with 'Institution:'"
assert any(l.lower().startswith("research area") for l in lines), "Expected a line starting with 'Research area:'"
print("Correct! Well done.")

# %% [markdown]
# ## Exercise 3: Unit conversion
#
# Write code to calculate the number of minutes in three hours.
#
# Expected output:
# ```
# 180
# ```

# %%
# %%capture my_output
# TODO: calculate and print the number of minutes in 3 hours

# %%
assert my_output.stdout.strip() == "180", (
    f"Not quite yet — your output was: {my_output.stdout!r}"
)
print("Correct! Well done.")

# %% [markdown]
# ## Exercise 4: HPC example
#
# A job ran for 9,600 seconds. Write code to calculate how many hours the job took.
#
# *Hint: There are 3,600 seconds in one hour.*
#
# Expected output:
# ```
# 2.6666666666666665
# ```
# This means the job took approximately 2.67 hours.

# %%
# %%capture my_output
# TODO: convert 9600 seconds into hours and print the result

# %%
assert my_output.stdout.strip() == "2.6666666666666665", (
    f"Not quite yet — your output was: {my_output.stdout!r}"
)
print("Correct! Well done.")

# %% [markdown]
# ## Exercise 5: Progress messages
#
# Write code that displays three progress messages for a research workflow, for example:
#
# ```
# Loading data
# Processing results
# Finished analysis
# ```
#
# **Extension:** Add comments above each line explaining what that stage represents.

# %%
# %%capture my_output
# TODO: print three progress messages
# Extension: add a comment above each line

# %%
lines = [l for l in my_output.stdout.splitlines() if l.strip()]
assert len(lines) >= 3, f"Expected at least 3 lines of output, got {len(lines)}."
print("Correct! Well done.")

# %% [markdown]
# ## Challenge exercise
#
# Modify one of the previous exercises by adding comments explaining each step of your code, for example:
#
# ```python
# # Display a message to show the script has started
# print("Starting runtime calculation")
#
# # Convert seconds to hours
# print(9600 / 3600)
#
# # Display a message to show the script has finished
# print("Finished")
# ```
#
# This challenge brings together three important ideas from the lesson: printing output, performing a calculation, and using comments to make your code easier to understand.
#
# *This one is open-ended, so there's no automatic check — ask a demonstrator or your instructor to look over your comments.*

# %%
# TODO: your challenge solution here

# %% [markdown]
# ## Further practice
#
# If you would like additional practice before moving on, write code that displays:
#
# - The title of your current project.
# - The current year.
# - The message `I am learning Python for HPC.`
#
# Add comments describing each section of your code. Example structure:
#
# ```python
# # Display project information
# print("Project: Galaxy simulation analysis")
#
# # Display the current year
# print(2026)
#
# # Display a learning message
# print("I am learning Python for HPC.")
# ```
#
# *This one is also open-ended, so there's no automatic check.*

# %%
# TODO: further practice

# %% [markdown]
# ## Well done!
#
# You've completed the exercises for this lesson. Revisit **Part 1: Concepts** any time you want to re-read the explanations or worked examples.
